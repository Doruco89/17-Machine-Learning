# %%
# 진짜를 놓쳤을때 문제가 되는 경우 = 재현율(recall) 이 중요 / ex) 암 진단, 보이스피싱 등
# 정밀도가 중요 / ex)스팸메일의 분류 실패 > 중요한 업무메일을 스팸메일로 분류하는 상황
# 임계값(Threshold) 1이냐 0이냐의 확률을 예측, 0.5 를 기준삼아 판단 반올림 > 1 , 내림 > 0 이 기준이되는 0.5가 임계값
# 이를 기준으로 TradeOff가 이루어짐 = 어느쪽 기준을 선택할지 선택의 갈림길

# %%
# F1 스코어 정밀도와 재현율의 조화 균형 / 가운데로갈때 사용
# F1 = 2 X (정밀도 / 재현율) / 
# ROC곡선 - 임계값 전체를 한눈에 보여줌
# AUC = ROC곡선 아래 면적, 0.5 ~ 1.0 / 1에 가까울수록 변별력이 좋다 - 불균형자료에서 잘작동 > 반드시 구해야 하는 값
