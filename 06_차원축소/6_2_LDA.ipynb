# %%
# LDA = 지도학습 / PCA와 거의같이가지만 y레이블도 포함

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
iris_sclaed = StandardScaler().fit_transform(iris.data)

# %%
lda = LinearDiscriminantAnalysis(n_components = 2) # 주요피쳐 2개 사용
lda.fit(iris_sclaed, iris.target)
iris_lda = lda.transform(iris_sclaed)
print(iris_lda.shape)
# Out:
# (150, 2)

# %%
import matplotlib.pyplot as plt

lda_cols = ["lda_1", "lda_2"] # 주요피처 2개 이름 지정
df_lda = pd.DataFrame(iris_lda, columns = lda_cols)
df_lda["target"] = iris.target

markers = ["^", "s", "o"]

for i, marker in enumerate(markers):
    x_data = df_lda[df_lda["target"] == i]["lda_1"]
    y_data = df_lda[df_lda["target"] == i]["lda_2"]
    plt.scatter(x_data,
                y_data,
                marker = marker,
                label = iris.target_names[i])

plt.legend()
plt.xlabel("lda_1")
plt.ylabel("lda_2")
plt.show()
